# %% [markdown]
# # Steered Model Testing Notebook
# Testing all functionality of the steered nnsight model with PyTorch hooks

# %%
import torch
import numpy as np
from model import Model
import matplotlib.pyplot as plt

# %%
# Use a small model for faster testing
model_name = "Qwen/Qwen3-0.6B"  # or "EleutherAI/pythia-70m" or "microsoft/phi-2"
model = Model(model_name)
print(f"Loaded model: {model_name}")
# Out:
# Loaded model: Qwen/Qwen3-0.6B

# %%
# Test single prompt
prompt = "The weather today is"
baseline_output = model.generate(prompt, max_new_tokens=30)
print("Baseline Output (single prompt):")
print(baseline_output)
print()
# Out:
# Setting `pad_token_id` to `eos_token_id`:tensor(..., device='meta', size=(), dtype=torch.int64) for open-end generation.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Test single prompt
#       2 prompt = "The weather today is"
# ----> 3 baseline_output = model.generate(prompt, max_new_tokens=30)
#       4 print("Baseline Output (single prompt):")
#       5 print(baseline_output)
#
# File ~/danhack/stursor/model.py:130, in Model.generate(self, prompts, max_new_tokens, **kwargs)
#     127 inputs = self.model.tokenizer(prompt, return_tensors="pt").to(self.model.device)
#     129 # Generate tokens (use _model which is the full model with LM head)
# --> 130 output_ids = self.model._model.generate(
#     131     **inputs,
#     132     max_new_tokens=max_new_tokens,
#     133     **kwargs
#     134 )
#     136 # Decode output
#     137 output_text = self.model.tokenizer.decode(output_ids[0], skip_special_tokens=True)
#
# File ~/danhack/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/danhack/.venv/lib/python3.12/site-packages/transformers/generation/utils.py:2431, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2428 batch_size = inputs_tensor.shape[0]
#    2430 device = inputs_tensor.device
# -> 2431 self._prepare_special_tokens(generation_config, kwargs_has_attention_mask, device=device)
#    2433 # decoder-only models must use left-padding for batched generation.
#    2434 if not self.config.is_encoder_decoder:
#    2435     # If `input_ids` was given, check if the last id in any sequence is `pad_token_id`
#    2436     # Note: If using, `inputs_embeds` this check does not work, because we want to be more hands-off.
#
# File ~/danhack/.venv/lib/python3.12/site-packages/transformers/generation/utils.py:2111, in GenerationMixin._prepare_special_tokens(self, generation_config, kwargs_has_attention_mask, device)
#    2105 if self.config.is_encoder_decoder and decoder_start_token_tensor is None:
#    2106     raise ValueError(
#    2107         "`decoder_start_token_id` or `bos_token_id` has to be defined for encoder-decoder generation."
#    2108     )
#    2109 if (
#    2110     eos_token_tensor is not None
# -> 2111     and isin_mps_friendly(elements=eos_token_tensor, test_elements=pad_token_tensor).any()
#    2112 ):
#    2113     if kwargs_has_attention_mask is not None and not kwargs_has_attention_mask:
#    2114         logger.warning_once(
#    2115             "The attention mask is not set and cannot be inferred from input because pad token is same as "
#    2116             "eos token. As a consequence, you may observe unexpected behavior. Please pass your input's "
#    2117             "`attention_mask` to obtain reliable results."
#    2118         )
#
# File ~/danhack/.venv/lib/python3.12/site-packages/torch/_meta_registrations.py:7341, in meta_local_scalar_dense(self)
#    7339 @register_meta(aten._local_scalar_dense)
#    7340 def meta_local_scalar_dense(self: Tensor):
# -> 7341     raise RuntimeError("Tensor.item() cannot be called on meta tensors")
#
# RuntimeError: Tensor.item() cannot be called on meta tensors

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       1 # Test multiple prompts
#       2 prompts = [
#       3     "The capital of France is",
#       4     "Artificial intelligence is",
#       5     "The meaning of life is"
#       6 ]
# ----> 7 baseline_outputs = model.generate(prompts, max_new_tokens=20)
#       8 print("Baseline Outputs (multiple prompts):")
#       9 for i, output in enumerate(baseline_outputs):
#
# NameError: name 'model' is not defined

# %%
# Out:
# Model structure:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Print model architecture summary
#       2 print("Model structure:")
# ----> 3 print(model.model.model)
#       4 print("\nNumber of layers:", len(model.model.model.transformer.h) if hasattr(model.model.model, 'transformer') else 'N/A')
#
# NameError: name 'model' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Get hidden dimension (typically 768 for GPT-2)
# ----> 2 if hasattr(model.model.model, 'transformer'):
#       3     # GPT-2 style
#       4     hidden_dim = model.model.model.transformer.wte.weight.shape[1]
#       5     num_layers = len(model.model.model.transformer.h)
#
# NameError: name 'model' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Create random steering vectors for testing
#       2 # Shape: (1, 1, hidden_dim) for broadcasting across batch and sequence
# ----> 3 random_vector_1 = torch.randn(1, 1, hidden_dim) * 0.1  # Small magnitude
#       4 random_vector_2 = torch.randn(1, 1, hidden_dim) * 0.5  # Medium magnitude
#       5 random_vector_3 = torch.randn(1, 1, hidden_dim) * 1.0  # Larger magnitude
#
# NameError: name 'hidden_dim' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Add steering to middle layer
# ----> 2 target_layer = f"{layer_prefix}.{num_layers // 2}"
#       3 print(f"Adding steering to layer: {target_layer}")
#       5 model.add_steering_vector(target_layer, random_vector_1, scale=1.0)
#
# NameError: name 'layer_prefix' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Generate with steering
# ----> 2 steered_output_1 = model.generate(prompt, max_new_tokens=30)
#       3 print("Steered Output (small random noise):")
#       4 print(steered_output_1)
#
# NameError: name 'model' is not defined
